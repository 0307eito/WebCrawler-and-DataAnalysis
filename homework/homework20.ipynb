# %% [markdown]
# # 動態網頁爬蟲 - API Request
#
# * 了解 API Request 用於動態網頁爬蟲的原理
# * 能夠使用 API Request 撰寫動態網頁爬蟲

# %% [markdown]
# ## 作業目標
#
# * 根據範例的教學，去找出 Dcard 中呼叫的 API 當中，有一個跟「取得所有看板」是哪一個？並且利用 Requests 呼叫。

# %% [markdown]
# * 請附上截圖：_______
# ![828.PNG](attachment:828.PNG)

# %%
import requests
import json

r = requests.get('https://www.dcard.tw/service/api/v2/posts?popular=true&limit=30')
d = json.loads(r.text)

d
# Out:
# [{'id': 234303040,
#   'title': '母親不支援上大學還偷我存款',
#   'excerpt': '我的母親是國小老師，她不支援我上大學，她說我自己有工作能力自己打工上學，去年她叫我好好讀書就好，她有存我的大學基金，結果今年認識了一位比她小的男朋友，兩個人每天煲電話約會，我一開始覺得媽媽離婚那麼久有',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': 'cd2959fe-5515-4c1e-bd35-1cd4c36b44f0',
#   'replyId': None,
#   'createdAt': '2020-08-27T06:22:42.044Z',
#   'updatedAt': '2020-08-27T08:37:42.552Z',
#   'commentCount': 1060,
#   'likeCount': 8510,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['新生', '爛媽', '難過', '抑鬱', '孤單'],
#   'meta': {'layout': 'classic'},
#   'globalPinned': None,
#   'forumName': '新生季',
#   'forumAlias': 'freshman',
#   'nsfw': False,
#   'gender': 'M',
#   'school': '國立高雄科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '932dc52c-d2e1-477b-8449-81563266386f',
#     'url': 'https://i.imgur.com/Kp4rymWl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/Kp4rymWl.jpg',
#     'thumbnail': 'https://i.imgur.com/Kp4rymWl.jpg',
# ...
